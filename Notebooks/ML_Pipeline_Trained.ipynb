# %%
# -------------------------------------------
# Notebook: ML_Pipeline_Trained.ipynb
# Purpose: Train and evaluate the ML pipeline
# -------------------------------------------

import sys
from pathlib import Path

from Tools.ML_Pipeline import PipelineConfig, MLPipeline
from sklearn.datasets import load_breast_cancer
import pandas as pd

# -----------------------------
# Load dataset
# -----------------------------
data = load_breast_cancer(as_frame=True)
df = data.frame

X = df.drop("target", axis=1)
y = df["target"]

# -----------------------------
# Initialize pipeline
# -----------------------------
config = PipelineConfig(
    test_size=0.2,
    random_state=42,
    cv_folds=5,
    log_level="INFO"
)

pipeline = MLPipeline(config)

# -----------------------------
# Prepare data, train, evaluate
# -----------------------------
pipeline.prepare_data(X, y)
pipeline.train()
metrics = pipeline.evaluate()
cv_results = pipeline.cross_validate()

print("Evaluation Metrics:", metrics)
print("Cross-Validation Results:", cv_results)

# -----------------------------
# Save pipeline and config
# -----------------------------

pipeline.save_model(str(save_dir / "ML_Pipeline_Model.joblib"))
pipeline.save_config(str(save_dir / "ML_Pipeline_Config.json"))

print("Pipeline and config saved successfully!")
# Out:
# 2025-12-07 16:17:05,940 - MLPipeline - INFO - Initialized pipeline with config: {'test_size': 0.2, 'random_state': 42, 'scaler_type': 'standard', 'model_type': 'random_forest', 'model_params': {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}, 'cv_folds': 5, 'log_level': 'INFO'}
# 2025-12-07 16:17:05,940 - MLPipeline - INFO - Initialized pipeline with config: {'test_size': 0.2, 'random_state': 42, 'scaler_type': 'standard', 'model_type': 'random_forest', 'model_params': {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}, 'cv_folds': 5, 'log_level': 'INFO'}
# 2025-12-07 16:17:05,940 - MLPipeline - INFO - Initialized pipeline with config: {'test_size': 0.2, 'random_state': 42, 'scaler_type': 'standard', 'model_type': 'random_forest', 'model_params': {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}, 'cv_folds': 5, 'log_level': 'INFO'}
# 2025-12-07 16:17:05,940 - MLPipeline - INFO - Initialized pipeline with config: {'test_size': 0.2, 'random_state': 42, 'scaler_type': 'standard', 'model_type': 'random_forest', 'model_params': {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}, 'cv_folds': 5, 'log_level': 'INFO'}
# 2025-12-07 16:17:05,940 - MLPipeline - INFO - Initialized pipeline with config: {'test_size': 0.2, 'random_state': 42, 'scaler_type': 'standard', 'model_type': 'random_forest', 'model_params': {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}, 'cv_folds': 5, 'log_level': 'INFO'}
# 2025-12-07 16:17:05,940 - MLPipeline - INFO - Initialized pipeline with config: {'test_size': 0.2, 'random_state': 42, 'scaler_type': 'standard', 'model_type': 'random_forest', 'model_params': {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}, 'cv_folds': 5, 'log_level': 'INFO'}
# 2025-12-07 16:17:05,940 - MLPipeline - INFO - Initialized pipeline with config: {'test_size': 0.2, 'random_state': 42, 'scaler_type': 'standard', 'model_type': 'random_forest', 'model_params': {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}, 'cv_folds': 5, 'log_level': 'INFO'}
# 2025-12-07 16:17:05,957 - MLPipeline - INFO - Starting data preparation
# 2025-12-07 16:17:05,957 - MLPipeline - INFO - Starting data preparation
# 2025-12-07 16:17:05,957 - MLPipeline - INFO - Starting data preparation
# 2025-12-07 16:17:05,957 - MLPipeline - INFO - Starting data preparation
# 2025-12-07 16:17:05,957 - MLPipeline - INFO - Starting data preparation
# 2025-12-07 16:17:05,957 - MLPipeline - INFO - Starting data preparation
# 2025-12-07 16:17:05,957 - MLPipeline - INFO - Starting data preparation
# 2025-12-07 16:17:05,987 - MLPipeline - INFO - Data split - Train: (455, 30), Test: (114, 30)
# 2025-12-07 16:17:05,987 - MLPipeline - INFO - Data split - Train: (455, 30), Test: (114, 30)
# 2025-12-07 16:17:05,987 - MLPipeline - INFO - Data split - Train: (455, 30), Test: (114, 30)
# 2025-12-07 16:17:05,987 - MLPipeline - INFO - Data split - Train: (455, 30), Test: (114, 30)
# 2025-12-07 16:17:05,987 - MLPipeline - INFO - Data split - Train: (455, 30), Test: (114, 30)
# 2025-12-07 16:17:05,987 - MLPipeline - INFO - Data split - Train: (455, 30), Test: (114, 30)
# 2025-12-07 16:17:05,987 - MLPipeline - INFO - Data split - Train: (455, 30), Test: (114, 30)
# 2025-12-07 16:17:06,008 - MLPipeline - INFO - Starting model training
# 2025-12-07 16:17:06,008 - MLPipeline - INFO - Starting model training
# 2025-12-07 16:17:06,008 - MLPipeline - INFO - Starting model training
# 2025-12-07 16:17:06,008 - MLPipeline - INFO - Starting model training
# 2025-12-07 16:17:06,008 - MLPipeline - INFO - Starting model training
# 2025-12-07 16:17:06,008 - MLPipeline - INFO - Starting model training
# 2025-12-07 16:17:06,008 - MLPipeline - INFO - Starting model training
# 2025-12-07 16:17:06,629 - MLPipeline - INFO - Model training completed
# 2025-12-07 16:17:06,629 - MLPipeline - INFO - Model training completed
# 2025-12-07 16:17:06,629 - MLPipeline - INFO - Model training completed
# 2025-12-07 16:17:06,629 - MLPipeline - INFO - Model training completed
# 2025-12-07 16:17:06,629 - MLPipeline - INFO - Model training completed
# 2025-12-07 16:17:06,629 - MLPipeline - INFO - Model training completed
# 2025-12-07 16:17:06,629 - MLPipeline - INFO - Model training completed
# 2025-12-07 16:17:06,641 - MLPipeline - INFO - Evaluating model
# 2025-12-07 16:17:06,641 - MLPipeline - INFO - Evaluating model
# 2025-12-07 16:17:06,641 - MLPipeline - INFO - Evaluating model
# 2025-12-07 16:17:06,641 - MLPipeline - INFO - Evaluating model
# 2025-12-07 16:17:06,641 - MLPipeline - INFO - Evaluating model
# 2025-12-07 16:17:06,641 - MLPipeline - INFO - Evaluating model
# 2025-12-07 16:17:06,641 - MLPipeline - INFO - Evaluating model
# 2025-12-07 16:17:06,700 - MLPipeline - INFO - Evaluation metrics: {'accuracy': 0.9649122807017544, 'precision': 0.9652053622194477, 'recall': 0.9649122807017544, 'f1': 0.9647382344750765}
# 2025-12-07 16:17:06,700 - MLPipeline - INFO - Evaluation metrics: {'accuracy': 0.9649122807017544, 'precision': 0.9652053622194477, 'recall': 0.9649122807017544, 'f1': 0.9647382344750765}
# 2025-12-07 16:17:06,700 - MLPipeline - INFO - Evaluation metrics: {'accuracy': 0.9649122807017544, 'precision': 0.9652053622194477, 'recall': 0.9649122807017544, 'f1': 0.9647382344750765}
# 2025-12-07 16:17:06,700 - MLPipeline - INFO - Evaluation metrics: {'accuracy': 0.9649122807017544, 'precision': 0.9652053622194477, 'recall': 0.9649122807017544, 'f1': 0.9647382344750765}
# 2025-12-07 16:17:06,700 - MLPipeline - INFO - Evaluation metrics: {'accuracy': 0.9649122807017544, 'precision': 0.9652053622194477, 'recall': 0.9649122807017544, 'f1': 0.9647382344750765}
# 2025-12-07 16:17:06,700 - MLPipeline - INFO - Evaluation metrics: {'accuracy': 0.9649122807017544, 'precision': 0.9652053622194477, 'recall': 0.9649122807017544, 'f1': 0.9647382344750765}
# 2025-12-07 16:17:06,700 - MLPipeline - INFO - Evaluation metrics: {'accuracy': 0.9649122807017544, 'precision': 0.9652053622194477, 'recall': 0.9649122807017544, 'f1': 0.9647382344750765}
# 2025-12-07 16:17:06,710 - MLPipeline - INFO - Starting 5-fold cross-validation
# 2025-12-07 16:17:06,710 - MLPipeline - INFO - Starting 5-fold cross-validation
# 2025-12-07 16:17:06,710 - MLPipeline - INFO - Starting 5-fold cross-validation
# 2025-12-07 16:17:06,710 - MLPipeline - INFO - Starting 5-fold cross-validation
# 2025-12-07 16:17:06,710 - MLPipeline - INFO - Starting 5-fold cross-validation
# 2025-12-07 16:17:06,710 - MLPipeline - INFO - Starting 5-fold cross-validation
# 2025-12-07 16:17:06,710 - MLPipeline - INFO - Starting 5-fold cross-validation
# 2025-12-07 16:17:08,428 - MLPipeline - INFO - Cross-validation scores: {'mean_cv_score': np.float64(0.9582417582417582), 'std_cv_score': np.float64(0.017582417582417565)}
# 2025-12-07 16:17:08,428 - MLPipeline - INFO - Cross-validation scores: {'mean_cv_score': np.float64(0.9582417582417582), 'std_cv_score': np.float64(0.017582417582417565)}
# 2025-12-07 16:17:08,428 - MLPipeline - INFO - Cross-validation scores: {'mean_cv_score': np.float64(0.9582417582417582), 'std_cv_score': np.float64(0.017582417582417565)}
# 2025-12-07 16:17:08,428 - MLPipeline - INFO - Cross-validation scores: {'mean_cv_score': np.float64(0.9582417582417582), 'std_cv_score': np.float64(0.017582417582417565)}
# 2025-12-07 16:17:08,428 - MLPipeline - INFO - Cross-validation scores: {'mean_cv_score': np.float64(0.9582417582417582), 'std_cv_score': np.float64(0.017582417582417565)}
# 2025-12-07 16:17:08,428 - MLPipeline - INFO - Cross-validation scores: {'mean_cv_score': np.float64(0.9582417582417582), 'std_cv_score': np.float64(0.017582417582417565)}
# 2025-12-07 16:17:08,428 - MLPipeline - INFO - Cross-validation scores: {'mean_cv_score': np.float64(0.9582417582417582), 'std_cv_score': np.float64(0.017582417582417565)}
# 2025-12-07 16:17:08,500 - MLPipeline - INFO - Model saved to c:\ML Engineer Journey\Models\ML_Pipeline_Model.joblib
# 2025-12-07 16:17:08,500 - MLPipeline - INFO - Model saved to c:\ML Engineer Journey\Models\ML_Pipeline_Model.joblib
# 2025-12-07 16:17:08,500 - MLPipeline - INFO - Model saved to c:\ML Engineer Journey\Models\ML_Pipeline_Model.joblib
# 2025-12-07 16:17:08,500 - MLPipeline - INFO - Model saved to c:\ML Engineer Journey\Models\ML_Pipeline_Model.joblib
# 2025-12-07 16:17:08,500 - MLPipeline - INFO - Model saved to c:\ML Engineer Journey\Models\ML_Pipeline_Model.joblib
# 2025-12-07 16:17:08,500 - MLPipeline - INFO - Model saved to c:\ML Engineer Journey\Models\ML_Pipeline_Model.joblib
# 2025-12-07 16:17:08,500 - MLPipeline - INFO - Model saved to c:\ML Engineer Journey\Models\ML_Pipeline_Model.joblib
# 2025-12-07 16:17:08,512 - MLPipeline - INFO - Config saved to c:\ML Engineer Journey\Models\ML_Pipeline_Config.json
# 2025-12-07 16:17:08,512 - MLPipeline - INFO - Config saved to c:\ML Engineer Journey\Models\ML_Pipeline_Config.json
# 2025-12-07 16:17:08,512 - MLPipeline - INFO - Config saved to c:\ML Engineer Journey\Models\ML_Pipeline_Config.json
# 2025-12-07 16:17:08,512 - MLPipeline - INFO - Config saved to c:\ML Engineer Journey\Models\ML_Pipeline_Config.json
# 2025-12-07 16:17:08,512 - MLPipeline - INFO - Config saved to c:\ML Engineer Journey\Models\ML_Pipeline_Config.json
# 2025-12-07 16:17:08,512 - MLPipeline - INFO - Config saved to c:\ML Engineer Journey\Models\ML_Pipeline_Config.json
# 2025-12-07 16:17:08,512 - MLPipeline - INFO - Config saved to c:\ML Engineer Journey\Models\ML_Pipeline_Config.json
# Evaluation Metrics: {'accuracy': 0.9649122807017544, 'precision': 0.9652053622194477, 'recall': 0.9649122807017544, 'f1': 0.9647382344750765}
# Cross-Validation Results: {'mean_cv_score': np.float64(0.9582417582417582), 'std_cv_score': np.float64(0.017582417582417565)}
# Pipeline and config saved successfully!
